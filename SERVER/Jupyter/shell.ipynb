# %%
import os

os.system("echo Hello from the other side!")
# Out:
# Hello from the other side!
# 0

# %%
import os
os.system("ls")
# Out:
# Jupyter.code-workspace
# shell.ipynb
# 0

# %% [markdown]
# # Press Play on this to activate ./venv

# %%
def activate():
    import os
    os.system("source /Users/daylannance/Documents/DEV/DDF/SERVER/venv/bin/activate")

# %%
os.system("top")
# Out:
# Processes: 614 total, 2 running, 612 sleeping, 2816 threads
# 2022/02/24 02:34:56
# Load Avg: 2.41, 2.15, 2.20
# CPU usage: 8.85% user, 14.28% sys, 76.86% idle
# SharedLibs: 388M resident, 55M data, 26M linkedit.
# MemRegions: 238968 total, 3062M resident, 150M private, 1828M shared.
# PhysMem: 16G used (2592M wired), 171M unused.
# VM: 22T vsize, 3099M framework vsize, 6552019(0) swapins, 7136763(0) swapouts.
# Networks: packets: 945490/783M in, 617633/166M out.
# Disks: 2368694/50G read, 1277626/45G written.
#
# PID    COMMAND          %CPU TIME     #TH   #WQ #PORTS MEM   PURG  CMPRS PGRP  PPID  STATE    BOOSTS    %CPU_ME %CPU_OTHRS UID FAULTS   COW    MSGSENT  MSGRECV  SYSBSD   SYSMACH   CSW       PAGEINS IDLEW   POWER INSTRS CYCLES USER                   #MREGS RPRVT VPRVT VSIZE KPRVT KSHRD
# ...
